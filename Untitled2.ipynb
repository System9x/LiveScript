# %% [markdown]
# <a href="https://colab.research.google.com/github/System9x/LiveScript/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/My Drive/Colabdata/
# !git clone https://github.com/System9x/i-Trace64.git
# !git clone https://github.com/pytorch/examples.git
# Out:
# Cloning into 'i-Trace64'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.email "koichi.sumiya@saint-gobain.com"
# !git config --global user.name "System9x"
